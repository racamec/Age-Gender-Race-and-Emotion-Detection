# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dropout, Flatten, Dense, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import os
from matplotlib import pyplot as plt
import numpy as np

IMG_HEIGHT=48 
IMG_WIDTH = 48
batch_size=32

train_data_dir='C:\\emotion_detection\\train\\'
validation_data_dir='C:\\emotion_detection\\test\\'

# %%
train_datagen = ImageDataGenerator(
rescale=1./255,
rotation_range=30,
shear_range=0.3,
zoom_range=0.3,
horizontal_flip=True,
fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
train_data_dir,
color_mode='grayscale',
target_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=batch_size,
class_mode='categorical',
shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
validation_data_dir,
color_mode='grayscale',
target_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=batch_size,
class_mode='categorical',
shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
#Verify our generator by plotting a few faces and printing corresponding labels
class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']

img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Create the model
model = Sequential()
model.add(Input(shape=(48, 48, 1)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 44, 44, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 20, 20, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,489,095 (9.50 MB)
#  Trainable params: 2,489,095 (9.50 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
train_path = "C:\\emotion_detection\\train\\"
test_path = "C:\\emotion_detection\\test\\"

num_train_imgs = 0
for root, dirs, files in os.walk(train_path):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(test_path):
    num_test_imgs += len(files)
    
    epochs=50

history=model.fit(train_generator,
                steps_per_epoch=num_train_imgs//batch_size,
                epochs=epochs,
                validation_data=validation_generator,
                validation_steps=num_test_imgs//batch_size)

model.save('emotion_detection_model_100epochs.h5')
# Out:
# Epoch 1/50
# C:\Users\pc\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 296s 326ms/step - accuracy: 0.2439 - loss: 1.8129 - val_accuracy: 0.3165 - val_loss: 1.6772
# Epoch 2/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 54us/step - accuracy: 0.2188 - loss: 1.8554 - val_accuracy: 0.4000 - val_loss: 1.5822
# Epoch 3/50
# C:\Users\pc\anaconda3\Lib\contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 123s 137ms/step - accuracy: 0.3218 - loss: 1.6912 - val_accuracy: 0.4336 - val_loss: 1.4497
# Epoch 4/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 35us/step - accuracy: 0.3125 - loss: 1.6753 - val_accuracy: 0.4000 - val_loss: 1.5266
# Epoch 5/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 127s 141ms/step - accuracy: 0.3986 - loss: 1.5399 - val_accuracy: 0.4678 - val_loss: 1.3641
# Epoch 6/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 37us/step - accuracy: 0.4375 - loss: 1.5628 - val_accuracy: 0.4000 - val_loss: 1.3964
# Epoch 7/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 129s 144ms/step - accuracy: 0.4426 - loss: 1.4454 - val_accuracy: 0.5133 - val_loss: 1.2868
# Epoch 8/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 36us/step - accuracy: 0.3750 - loss: 1.5840 - val_accuracy: 0.4000 - val_loss: 1.5131
# Epoch 9/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 130s 145ms/step - accuracy: 0.4687 - loss: 1.3812 - val_accuracy: 0.5151 - val_loss: 1.2517
# Epoch 10/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 35us/step - accuracy: 0.5000 - loss: 1.3738 - val_accuracy: 0.3000 - val_loss: 1.3873
# Epoch 11/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 131s 146ms/step - accuracy: 0.4898 - loss: 1.3479 - val_accuracy: 0.5458 - val_loss: 1.1872
# Epoch 12/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 32us/step - accuracy: 0.5000 - loss: 1.0566 - val_accuracy: 0.3000 - val_loss: 1.5089
# Epoch 13/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 131s 146ms/step - accuracy: 0.4983 - loss: 1.3069 - val_accuracy: 0.5437 - val_loss: 1.1954
# Epoch 14/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 36us/step - accuracy: 0.3438 - loss: 1.5583 - val_accuracy: 0.5000 - val_loss: 1.1599
# Epoch 15/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 132s 147ms/step - accuracy: 0.5117 - loss: 1.2807 - val_accuracy: 0.5539 - val_loss: 1.1686
# Epoch 16/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 34us/step - accuracy: 0.5312 - loss: 1.1011 - val_accuracy: 0.7000 - val_loss: 0.8694
# Epoch 17/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 132s 147ms/step - accuracy: 0.5134 - loss: 1.2592 - val_accuracy: 0.5576 - val_loss: 1.1615
# Epoch 18/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 0.5938 - loss: 1.3248 - val_accuracy: 0.4000 - val_loss: 1.3991
# Epoch 19/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 134s 149ms/step - accuracy: 0.5248 - loss: 1.2505 - val_accuracy: 0.5702 - val_loss: 1.1331
# Epoch 20/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 35us/step - accuracy: 0.5312 - loss: 1.3175 - val_accuracy: 0.9000 - val_loss: 0.8303
# Epoch 21/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 133s 148ms/step - accuracy: 0.5283 - loss: 1.2322 - val_accuracy: 0.5696 - val_loss: 1.1385
# Epoch 22/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 31us/step - accuracy: 0.3438 - loss: 1.5115 - val_accuracy: 0.8000 - val_loss: 1.1258
# Epoch 23/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 133s 148ms/step - accuracy: 0.5337 - loss: 1.2358 - val_accuracy: 0.5628 - val_loss: 1.1499
# Epoch 24/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 37us/step - accuracy: 0.5312 - loss: 1.4316 - val_accuracy: 0.4000 - val_loss: 1.6885
# Epoch 25/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 133s 148ms/step - accuracy: 0.5409 - loss: 1.2179 - val_accuracy: 0.5675 - val_loss: 1.1271
# Epoch 26/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 32us/step - accuracy: 0.3750 - loss: 1.3988 - val_accuracy: 0.7000 - val_loss: 0.9699
# Epoch 27/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 133s 148ms/step - accuracy: 0.5408 - loss: 1.2058 - val_accuracy: 0.5872 - val_loss: 1.0991
# Epoch 28/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 36us/step - accuracy: 0.5000 - loss: 1.2912 - val_accuracy: 0.5000 - val_loss: 1.1771
# Epoch 29/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 133s 148ms/step - accuracy: 0.5423 - loss: 1.2001 - val_accuracy: 0.5791 - val_loss: 1.1129
# Epoch 30/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 37us/step - accuracy: 0.6250 - loss: 1.2931 - val_accuracy: 0.3000 - val_loss: 1.3594
# Epoch 31/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 133s 148ms/step - accuracy: 0.5484 - loss: 1.1951 - val_accuracy: 0.5720 - val_loss: 1.1146
# Epoch 32/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 33us/step - accuracy: 0.5625 - loss: 1.2583 - val_accuracy: 0.3000 - val_loss: 1.9290
# Epoch 33/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 134s 149ms/step - accuracy: 0.5514 - loss: 1.1862 - val_accuracy: 0.5873 - val_loss: 1.0983
# Epoch 34/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 34us/step - accuracy: 0.4688 - loss: 1.0538 - val_accuracy: 0.6000 - val_loss: 0.9481
# Epoch 35/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 133s 148ms/step - accuracy: 0.5562 - loss: 1.1717 - val_accuracy: 0.5788 - val_loss: 1.1046
# Epoch 36/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 0.4062 - loss: 1.3968 - val_accuracy: 0.3000 - val_loss: 1.6129
# Epoch 37/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 135s 151ms/step - accuracy: 0.5574 - loss: 1.1707 - val_accuracy: 0.5949 - val_loss: 1.0645
# Epoch 38/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 34us/step - accuracy: 0.6562 - loss: 0.9802 - val_accuracy: 0.4000 - val_loss: 1.0504
# Epoch 39/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 133s 148ms/step - accuracy: 0.5492 - loss: 1.1757 - val_accuracy: 0.5953 - val_loss: 1.0685
# Epoch 40/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 35us/step - accuracy: 0.5000 - loss: 1.1220 - val_accuracy: 0.7000 - val_loss: 1.0446
# Epoch 41/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 134s 150ms/step - accuracy: 0.5681 - loss: 1.1468 - val_accuracy: 0.5960 - val_loss: 1.0693
# Epoch 42/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 36us/step - accuracy: 0.6250 - loss: 1.0464 - val_accuracy: 0.5000 - val_loss: 1.2028
# Epoch 43/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 134s 149ms/step - accuracy: 0.5617 - loss: 1.1477 - val_accuracy: 0.6016 - val_loss: 1.0536
# Epoch 44/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 36us/step - accuracy: 0.5625 - loss: 1.2257 - val_accuracy: 0.8000 - val_loss: 0.7411
# Epoch 45/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 134s 149ms/step - accuracy: 0.5554 - loss: 1.1585 - val_accuracy: 0.5876 - val_loss: 1.0842
# Epoch 46/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 0.5000 - loss: 1.1906 - val_accuracy: 0.5000 - val_loss: 1.1239
# Epoch 47/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 134s 149ms/step - accuracy: 0.5632 - loss: 1.1414 - val_accuracy: 0.5977 - val_loss: 1.0652
# Epoch 48/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 37us/step - accuracy: 0.4062 - loss: 1.4734 - val_accuracy: 0.7000 - val_loss: 0.7151
# Epoch 49/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 136s 151ms/step - accuracy: 0.5713 - loss: 1.1391 - val_accuracy: 0.5919 - val_loss: 1.0716
# Epoch 50/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 34us/step - accuracy: 0.5938 - loss: 0.9616 - val_accuracy: 0.6000 - val_loss: 1.0472
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model


#Test the model
my_model = load_model('emotion_detection_model_100epochs.h5', compile=False)

#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=my_model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step

# %%
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
# Out:
# Accuracy =  0.59375

# %%
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
